# %%
# Importing necessary library
import Augmentor
# Passing the path of the image directory
p = Augmentor.Pipeline('C:/Users/user/Projekt/ss/train')
 
# Defining augmentation parameters and generating 5 samples
p.flip_left_right(0.5)
p.black_and_white(0.1)
p.rotate(1, 15, 10)
p.skew(1, 0.5)
p.zoom(probability = 1, min_factor = 1.1, max_factor = 1.5)
p.sample(1)
# Out:
# Initialised with 1 image(s) found.
# Output directory set to C:/Users/user/Projekt/ss/train\output.
# Processing <PIL.Image.Image image mode=L size=48x48 at 0x18E2D3A3E00>: 100%|██████████| 1/1 [00:00<00:00, 166.50 Samples/s]

# %%
import tensorflow as tf
import numpy as np

image = np.random.rand(1,32,32,3) 
conv1 = tf.keras.layers.Conv2D(filters=20,kernel_size=(5,5), padding="valid")
output1 = conv1(image)
output1
# Out:
# <tf.Tensor: shape=(1, 28, 28, 20), dtype=float32, numpy=
# array([[[[ 0.0050512 ,  0.13350634,  0.20719066, ..., -0.44942394,
#            0.08610892,  0.14170665],
#          [ 0.307874  , -0.05153949,  0.50798243, ..., -0.23576997,
#           -0.15526348,  0.35255945],
#          [ 0.07838488,  0.04011106,  0.35419556, ..., -0.25432995,
#            0.22493137, -0.06667519],
#          ...,
#          [-0.02811797, -0.07671866,  0.5189281 , ..., -0.00811294,
#           -0.12194825,  0.22022218],
#          [ 0.23758297,  0.11711541,  0.27643028, ..., -0.45058602,
#           -0.06192152,  0.23389065],
#          [ 0.24471663, -0.00563421,  0.22685549, ..., -0.15038097,
#            0.04543807,  0.3892837 ]],
#
#         [[ 0.19762546,  0.11488625,  0.38521576, ..., -0.0852793 ,
#            0.32880974,  0.20440777],
#          [-0.03906621, -0.02774648,  0.5532364 , ..., -0.3093417 ,
#           -0.20809118,  0.49578848],
#          [ 0.19453162,  0.06428039,  0.21647556, ..., -0.07509118,
#            0.18246725,  0.20431253],
#          ...,
#          [-0.13877499,  0.01171764,  0.18847813, ..., -0.46058202,
#           -0.05160348,  0.12255844],
#          [ 0.02579482,  0.14398919,  0.2579158 , ..., -0.30271456,
#           -0.00283886,  0.19730526],
#          [ 0.05953301, -0.21297695,  0.25942206, ..., -0.48003766,
#           -0.20189163,  0.28435105]],
#
#         [[ 0.25964385,  0.05559876,  0.0595838 , ..., -0.38939247,
#            0.05915664,  0.10716304],
#          [-0.13553311, -0.16066517,  0.27699554, ..., -0.3731591 ,
#            0.37120378,  0.142296  ],
#          [-0.17095059, -0.05309116,  0.16826262, ..., -0.620029  ,
#           -0.17485791,  0.3906806 ],
#          ...,
#          [ 0.2339803 , -0.05780492,  0.18187742, ..., -0.41049388,
#            0.18300022,  0.32072058],
#          [-0.07504207,  0.33969104,  0.43567908, ..., -0.43842965,
#            0.05917548,  0.55722046],
#          [ 0.11591437,  0.3985158 ,  0.5028496 , ..., -0.6110465 ,
#            0.18707915,  0.47234693]],
#
#         ...,
#
#         [[ 0.12568776,  0.23364706,  0.12487639, ..., -0.52704304,
#           -0.03278753,  0.06644081],
#          [ 0.21155764,  0.10187764,  0.28860843, ..., -0.2712779 ,
#           -0.00464436,  0.2086723 ],
#          [-0.03343243,  0.10333368,  0.24889973, ..., -0.54566133,
#           -0.0560429 ,  0.4044759 ],
#          ...,
#          [-0.20432162, -0.01214797,  0.2998011 , ..., -0.3054643 ,
#            0.02958053,  0.2200431 ],
#          [ 0.22082579,  0.54626304,  0.24871762, ..., -0.4677707 ,
#           -0.04592888,  0.17021362],
#          [ 0.2788282 ,  0.1026031 ,  0.3147407 , ..., -0.21147785,
#            0.00130282,  0.16018422]],
#
#         [[ 0.08502339, -0.12134407,  0.4104733 , ..., -0.3866074 ,
#           -0.11223663,  0.34531683],
#          [ 0.3248265 ,  0.05170296,  0.00610032, ..., -0.37098685,
#           -0.09389725,  0.41298306],
#          [ 0.01846161,  0.06728101,  0.18313736, ..., -0.26341736,
#           -0.04128677,  0.13668202],
#          ...,
#          [ 0.03880268,  0.21815462,  0.48649272, ..., -0.28646284,
#            0.14377803,  0.32453033],
#          [ 0.11894376, -0.01059204,  0.33886546, ..., -0.28819802,
#            0.18603721,  0.11758161],
#          [-0.05783641,  0.08913663,  0.3126105 , ..., -0.17236136,
#            0.27939945,  0.13363816]],
#
#         [[-0.17929591, -0.15995787,  0.36731124, ..., -0.32371676,
#            0.03473466,  0.2918887 ],
#          [ 0.06083936,  0.09863997,  0.3671541 , ..., -0.47696477,
#            0.07922628,  0.45723784],
#          [ 0.20438552, -0.03236008,  0.20701516, ..., -0.3140991 ,
#            0.05853226,  0.2996391 ],
#          ...,
#          [ 0.03372642,  0.02340725,  0.6373861 , ..., -0.13956633,
#           -0.07997053,  0.36360064],
#          [-0.21300764,  0.04881156,  0.216724  , ..., -0.19173618,
#            0.01853443,  0.03634859],
#          [ 0.39654368,  0.1219286 ,  0.12317835, ..., -0.20097117,
#            0.29159343,  0.15243568]]]], dtype=float32)>
